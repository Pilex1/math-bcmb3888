# %%
import networkx as nx
import numpy as np
import scipy as sp
from networkx.algorithms import community
from networkx.algorithms.community import greedy_modularity_communities
from networkx.algorithms.community import k_clique_communities
from community import community_louvain
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering
from sklearn import metrics

# %%
G0 = nx.read_weighted_edgelist("4932.protein.links.v11.5.txt",comments="#",nodetype=str)
print(f"number of nodes in original dataset: ", len(G0.nodes))

#removing the prefix in proteins
protein_info = pd.read_csv("Protein_info.txt", sep='\t')
map_dic = protein_info.set_index('#string_protein_id').to_dict()['preferred_name']
   
G = nx.relabel_nodes(G0, map_dic)

# remove essential proteins
essential_proteins = pd.read_csv("yeast essential proteins.csv", header=None)[1]
print()
print(essential_proteins)
G.remove_nodes_from(essential_proteins)
print(f"number of nodes after removing essential proteins: ", len(G.nodes))  

# delete those edges with a combined score of <= threshold_score (small confidence)
threshold_score = 500
for edge in G.edges: 
    weight = list(G.get_edge_data(edge[0],edge[1]).values())
    if(weight[0] <= threshold_score):
        G.remove_edge(edge[0],edge[1])
# Out:
# number of nodes in original dataset:  6394
#
# 0         YAL001C
# 1         YAL003W
# 2         YAL012W
# 3         YAL025C
# 4         YAL032C
#           ...
# 1308    YKL138C-A
# 1309    YNL138W-A
# 1310    YNL024C-A
# 1311    YHR199C-A
# 1312    YIL102C-A
# Name: 1, Length: 1313, dtype: object
# number of nodes after removing essential proteins:  6324

# %%
#protein_interest = ['YER178W', 'YBR221C', 'YNL071W', 'YOR090C', 'YFL018C', 'YIL042C', 'YGL059W']

# %%
#nx.common_neighbors(G, protein_interest[0], protein_interest[1])
# Out:
# <generator object common_neighbors.<locals>.<genexpr> at 0x7fb84025c740>

# %% [markdown]
# ## Louvain and Centrality Measures

# %%
partLouvain = community_louvain.best_partition(G)
number_of_communities = max(partLouvain.values())+1 #We add one because the indexing starts at 0.
print('# of partitions for Louvain modularity =',number_of_communities)
communities = {} #empty dictionary
for i in range(number_of_communities):
    communities[i] = [] #create an empty list for each community

for name, community in partLouvain.items():
    communities[community].append(name) #go through the computed partition and add each node to the appropriate list
# Out:
# # of partitions for Louvain modularity = 309

# %%
protein_interest = ['PDA1', 'PDB1', 'LAT1', 'LPD1', 'PKP1', 'PKP2', 'PTC5']
communities_interest = set()

for p in protein_interest:
    print(f"protein {p} in community {partLouvain[p]}")
    communities_interest.add(partLouvain[p])

#PDA1, PDB1, LAT1, LPD1, 
#PKP1, PKP2,PTC5
# Out:
# protein PDA1 in community 5
# protein PDB1 in community 5
# protein LAT1 in community 5
# protein LPD1 in community 5
# protein PKP1 in community 10
# protein PKP2 in community 10
# protein PTC5 in community 10

# %%
print(number_of_communities)
print(communities[309])
# Out:
# 310
# ['YPL136W']

# %% [markdown]
# Below is a code to obtain a subset of G with only community 2 and 7

# %%
G_PDH = G.subgraph(communities[list(communities_interest)[0]]) #subgraph of community with PDH Complex
G_enz = G.subgraph(communities[list(communities_interest)[1]]) #subgraph of community with phosphatase and kinase

# %%
list(communities_interest)
# Out:
# [10, 5]

# %%
nx.draw(G_PDH)

# %%
nx.draw(G_enz, node_color = 'red')

# %% [markdown]
# The code below finds the 10 nodes with the highest centrality measure within the PDH complex community

# %%
PDH_dict = nx.degree_centrality(G_PDH)
PDH_centrality = sorted(PDH_dict.items(), key=lambda item: item[1], reverse=True)
PDH_centrality[0:10]
# Out:
# [('ACT1', 0.1811646297627606),
#  ('CDC42', 0.1710999281092739),
#  ('SEC4', 0.13587347232207045),
#  ('SNC1', 0.13084112149532712),
#  ('RHO1', 0.12724658519051044),
#  ('YPT7', 0.12437095614665708),
#  ('CHC1', 0.12149532710280374),
#  ('RAS2', 0.1186196980589504),
#  ('ARF1', 0.11718188353702373),
#  ('YPT1', 0.11502516175413371)]

# %%
#using eigenvector centrality
sorted(nx.eigenvector_centrality(G_PDH).items(), key = lambda item:item[1], reverse = True)[0:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-44cd41978e3c> in <module>
#       1 #using eigenvector centrality
# ----> 2 sorted(nx.eigenvector_centrality(G_PDH, alpha=0.1, beta=1.0, max_iter=1000, tol=1e-06, nstart=None, normalized=True, weight=None).items(), key = lambda item:item[1], reverse = True)[0:10]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229         def fun(*args, **kw):
#     230             if not kwsyntax:
# --> 231                 args, kw = fix(args, kw, sig)
#     232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fix(args, kwargs, sig)
#     201     Fix args and kwargs to be consistent with the signature
#     202     """
# --> 203     ba = sig.bind(*args, **kwargs)
#     204     ba.apply_defaults()  # needed for test_dan_schult
#     205     return ba.args, ba.kwargs
#
# ~/opt/anaconda3/lib/python3.8/inspect.py in bind(self, *args, **kwargs)
#    3035         if the passed arguments can not be bound.
#    3036         """
# -> 3037         return self._bind(args, kwargs)
#    3038
#    3039     def bind_partial(self, /, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/inspect.py in _bind(self, args, kwargs, partial)
#    3024                 arguments[kwargs_param.name] = kwargs
#    3025             else:
# -> 3026                 raise TypeError(
#    3027                     'got an unexpected keyword argument {arg!r}'.format(
#    3028                         arg=next(iter(kwargs))))
#
# TypeError: got an unexpected keyword argument 'alpha'

# %% [markdown]
# Look at degree distribution next?

# %% [markdown]
# We repeat the same process for the kinase and phosphatase community

# %%
Enz_dict = nx.degree_centrality(G_enz)
Enz_centrality = sorted(Enz_dict.items(), key=lambda item: item[1], reverse=True)
Enz_centrality[0:10]
# Out:
# [('PGM2', 0.11935266351989211),
#  ('ZWF1', 0.11598111935266352),
#  ('TRP5', 0.1112609575185435),
#  ('TPI1', 0.11058664868509778),
#  ('NQM1', 0.10451786918408631),
#  ('GAD1', 0.10384356035064059),
#  ('CTT1', 0.10384356035064059),
#  ('PGK1', 0.10316925151719487),
#  ('ALD3', 0.10114632501685772),
#  ('TRP3', 0.09777478084962912)]

# %%
sorted(nx.eigenvector_centrality(G_enz).items(), key = lambda item:item[1], reverse = True)[0:10]
# Out:
# [('ZWF1', 0.13257980741347514),
#  ('TPI1', 0.13084949622425518),
#  ('PGM2', 0.12392501742758101),
#  ('PGK1', 0.11838453115876908),
#  ('NQM1', 0.11759140355526537),
#  ('PGI1', 0.11753795924020496),
#  ('GLK1', 0.11279105311657758),
#  ('ALD3', 0.1119011988394797),
#  ('FUM1', 0.10930817801964626),
#  ('HXK1', 0.10829725210744727)]
